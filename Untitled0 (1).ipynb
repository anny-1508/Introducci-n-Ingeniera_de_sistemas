# %%
NUM = float(input("Ingrese un número:"))
CUADRADO = NUM ** 2
CUBO = NUM ** 3
print("El cuadrado es:", CUADRADO)
print("El cubo es", CUBO)
# Out:
# Ingrese un número:8
# El cuadrado es: 64.0
# El cubo es 512.0

# %%
import math

radio = float(input("Ingrese el radio del círculo: "))

area = math.pi * radio ** 2
longitud = 2 * math.pi * radio

print("El área del círculo es:", round(area, 2))
print("La longitud de la circunferencia es:", round(longitud, 2))
# Out:
# Ingrese el radio del círculo: 9
# El área del círculo es: 254.47
# La longitud de la circunferencia es: 56.55
